# %%
# !pip install -q --force-reinstall --no-deps git+https://github.com/rbennum/telco-churn.git@main

# %%
import importlib, telco_churn.hello
importlib.reload(telco_churn.hello)
print(telco_churn.hello.greet())

# %% [markdown]
# # testing scaffold
#
# edited in kaggle
